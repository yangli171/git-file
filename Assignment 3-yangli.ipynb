# %%
import requests
response = requests.get("https://www.azlyrics.com/lyrics/daftpunk/onemoretime.html")
html_string = response.text
print(html_string)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <meta name="description" content="Daft Punk &quot;One More Time&quot;: One more time One more time One more time We're gonna celebrate Oh yeah, all right Don't stop the d...">
# <meta name="keywords" content="One More Time lyrics, Daft Punk One More Time lyrics, Daft Punk lyrics">
# <meta name="robots" content="noarchive">
# <meta property="og:image" content="//www.azlyrics.com/az_logo_tr.png">
# <title>Daft Punk - One More Time Lyrics | AZLyrics.com</title>
#
# <link rel="canonical" href="https://www.azlyrics.com/lyrics/daftpunk/onemoretime.html" />
# <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css">
# <link rel="stylesheet" href="/local/az.css">
#
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# ...

# %%
from bs4 import BeautifulSoup
response = requests.get("https://www.azlyrics.com/lyrics/daftpunk/onemoretime.html")
html_string = response.text

document = BeautifulSoup(html_string, "html.parser")

document
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Daft Punk &quot;One More Time&quot;: One more time One more time One more time We're gonna celebrate Oh yeah, all right Don't stop the d..." name="description"/>
# <meta content="One More Time lyrics, Daft Punk One More Time lyrics, Daft Punk lyrics" name="keywords"/>
# <meta content="noarchive" name="robots"/>
# <meta content="//www.azlyrics.com/az_logo_tr.png" property="og:image"/>
# <title>Daft Punk - One More Time Lyrics | AZLyrics.com</title>
# <link href="https://www.azlyrics.com/lyrics/daftpunk/onemoretime.html" rel="canonical"/>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/local/az.css" rel="stylesheet"/>
# ...

# %%
document.find("div")
# Out:
# <div class="container">
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <button class="navbar-toggle collapsed" data-target="#search-collapse" data-toggle="collapse" type="button">
# <span class="glyphicon glyphicon-search"></span>
# </button>
# <button class="navbar-toggle collapsed" data-target="#artists-collapse" data-toggle="collapse" type="button">
# <span class="glyphicon glyphicon-th-list"></span>
# </button>
# <a class="navbar-brand" href="//www.azlyrics.com"><img alt="AZLyrics.com" class="pull-left" src="//www.azlyrics.com/az_logo_tr.png" style="max-height:40px; margin-top:-10px;"/></a>
# </div>
# <ul class="collapse navbar-collapse nav navbar-nav" id="artists-collapse">
# <li>
# <div class="btn-group text-center" role="group">
# <a class="btn btn-menu" href="//www.azlyrics.com/a.html">A</a>
# <a class="btn btn-menu" href="//www.azlyrics.com/b.html">B</a>
# <a class="btn btn-menu" href="//www.azlyrics.com/c.html">C</a>
# ...

# %%
document.find("div", attrs={"class": "col-xs-12 col-lg-8 text-center"}).text.replace('\n','').replace('\\','')
# Out:
# '"One More Time" lyricsDaft Punk Lyrics"One More Time"\rOne more timeOne more timeOne more timeWe\'re gonna celebrateOh yeah, all rightDon\'t stop the dancingOne more timeWe\'re gonna celebrateOh yeah, all rightDon\'t stop the dancingOne more timeWe\'re gonna celebrateOh yeah, all rightDon\'t stop the dancingOne more timeWe\'re gonna celebrateOh yeahOne more timeOne more timeWe\'re gonna celebrateOh yeah, all rightDon\'t stop the dancingOne more timeWe\'re gonna celebrateOh yeahDon\'t stop the dancingOne more timeI\'m just feelin\'Celebration tonightCelebrateDon\'t wait too lateNo he don\'t stopYou can\'t stopWe\'re gonna celebrateOne more timeOne more timeOne more timeCelebrationYou know we\'re gonna do it rightTonightHey! Just feelin\'Music\'s got me feeling the need needCome on, all rightWe\'re gonna celebrateOne more timeCelebrate and dance so freeMusic\'s got me feeling so freeCelebrate and dance so freeOne more timeMusic\'s got me feeling so freeWe\'re gonna celebrateCelebrate 
# ...

# %%
lyrics = document.find("div", attrs={"class": "col-xs-12 col-lg-8 text-center"}).text.replace('\n','').replace('\\','')

# %%
document.find("h1").text
# Out:
# '"One More Time" lyrics'

# %%
type(document.find("h1").text)
# Out:
# str

# %%
document.find("h2").text
# Out:
# 'Daft Punk Lyrics'

# %%
type(document.find("h2").text)
# Out:
# str

# %%
Dataset_artist = document.find("h1").text

# %%
Dataset_artist
# Out:
# '"One More Time" lyrics'

# %%
Dataset_title = document.find("h2").text

# %%
Dataset_title
# Out:
# 'Daft Punk Lyrics'

# %%
Dataset_lyrics = lyrics

# %%
Dataset_lyrics
# Out:
# '"One More Time" lyricsDaft Punk Lyrics"One More Time"\rOne more timeOne more timeOne more timeWe\'re gonna celebrateOh yeah, all rightDon\'t stop the dancingOne more timeWe\'re gonna celebrateOh yeah, all rightDon\'t stop the dancingOne more timeWe\'re gonna celebrateOh yeah, all rightDon\'t stop the dancingOne more timeWe\'re gonna celebrateOh yeahOne more timeOne more timeWe\'re gonna celebrateOh yeah, all rightDon\'t stop the dancingOne more timeWe\'re gonna celebrateOh yeahDon\'t stop the dancingOne more timeI\'m just feelin\'Celebration tonightCelebrateDon\'t wait too lateNo he don\'t stopYou can\'t stopWe\'re gonna celebrateOne more timeOne more timeOne more timeCelebrationYou know we\'re gonna do it rightTonightHey! Just feelin\'Music\'s got me feeling the need needCome on, all rightWe\'re gonna celebrateOne more timeCelebrate and dance so freeMusic\'s got me feeling so freeCelebrate and dance so freeOne more timeMusic\'s got me feeling so freeWe\'re gonna celebrateCelebrate 
# ...

# %%
Dataset = []
Dataset.append(Dataset_artist)
Dataset.append(Dataset_title)
Dataset.append(Dataset_lyrics)

# %%
Dataset
# Out:
# ['"One More Time" lyrics',
#  'Daft Punk Lyrics',
# ...
